# %%
import STAGATE
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys
from sklearn import metrics
from pathlib import Path

# %%
# adata = sc.read_h5ad('../data/MERFISH/MERFISH_0.09.h5ad')
# adata = sc.read_h5ad('../data/BaristaSeq/Slice_3_removed.h5ad')
adata = sc.read_h5ad('../data/osmfish/osmfish_remove_excluded.h5ad')
print(adata)
adata.var_names_make_unique()
n_clusters = len(adata.obs['Region'].unique())
# Out:
# AnnData object with n_obs × n_vars = 4839 × 33
#     obs: 'ClusterName', 'ClusterID', 'Region'
#     uns: 'ClusterName_colors'
#     obsm: 'spatial'

# %%
sc.pp.highly_variable_genes(adata, flavor="seurat_v3", n_top_genes=3000)
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)
# Out:
# /data/hgh/anaconda3/envs/STAGATE/lib/python3.7/site-packages/scanpy/preprocessing/_highly_variable_genes.py:64: UserWarning: `flavor='seurat_v3'` expects raw count data, but non-integers were found.
#   UserWarning,

# %%
STAGATE.Cal_Spatial_Net(adata, rad_cutoff=150)
STAGATE.Stats_Spatial_Net(adata)
# Out:
# ------Calculating spatial graph...
# The graph contains 2180 edges, 4839 cells.
# 0.4505 neighbors per cell on average.

# %%
adata = STAGATE.train_STAGATE(adata, alpha=0)
# Out:
# Size of Input:  (4839, 33)
# WARNING:tensorflow:From /data/hgh/anaconda3/envs/STAGATE/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1375: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2025-01-13 14:27:45.314435: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA
# 2025-01-13 14:27:45.357757: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2400000000 Hz
# 2025-01-13 14:27:45.369292: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55b86e518000 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2025-01-13 14:27:45.369346: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2025-01-13 14:27:45.373475: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2025-01-13 14:27:45.561693: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55b86e58fe40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-01-13 14:27:45.561750: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-PCIE-32GB, Compute Capability 7.0
# 2025-01-13 14:27:45.561765: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): Tesla V100-PCIE-32GB, Compute Capability 7.0
# 2025-01-13 14:27:45.564710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-PCIE-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0000:9b:00.0
# 2025-01-13 14:27:45.567207: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 1 with properties:
# name: Tesla V100-PCIE-32GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0000:c8:00.0
# 2025-01-13 14:27:45.567657: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2025-01-13 14:27:45.570424: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 2025-01-13 14:27:45.572775: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10.0
# 2025-01-13 14:27:45.573326: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10.0
# 2025-01-13 14:27:45.576546: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10.0
# 2025-01-13 14:27:45.578080: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10.0
# 2025-01-13 14:27:45.581129: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2025-01-13 14:27:45.584185: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0, 1
# 2025-01-13 14:27:45.584254: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# 2025-01-13 14:27:45.585908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-01-13 14:27:45.585923: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0 1
# 2025-01-13 14:27:45.585928: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N Y
# 2025-01-13 14:27:45.585930: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 1:   Y N
# 2025-01-13 14:27:45.588314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 27046 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:9b:00.0, compute capability: 7.0)
# 2025-01-13 14:27:45.589699: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 27561 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-32GB, pci bus id: 0000:c8:00.0, compute capability: 7.0)
#   0%|                                                                                                                                                       | 0/500 [00:00<?, ?it/s]2025-01-13 14:27:46.160698: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10.0
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:07<00:00, 66.37it/s]

# %%
adata = STAGATE.mclust_R(adata, used_obsm='STAGATE', num_cluster=n_clusters)
# Out:
# R[write to console]:                    __           __
#    ____ ___  _____/ /_  _______/ /_
#   / __ `__ \/ ___/ / / / / ___/ __/
#  / / / / / / /__/ / /_/ (__  ) /_
# /_/ /_/ /_/\___/_/\__,_/____/\__/   version 6.1.1
# Type 'citation("mclust")' for citing this R package in publications.
# fitting ...
#   |======================================================================| 100%

# %%
obs_df = adata.obs.dropna()
ARI = metrics.adjusted_rand_score(obs_df['mclust'], obs_df['Region'])
NMI = metrics.normalized_mutual_info_score(obs_df['mclust'], obs_df['Region'])
print('Adjusted rand index = %.4f' %ARI)
# Out:
# Adjusted rand index = 0.0956

# %%
fig, ax = plt.subplots(1, 1, figsize=(4, 4))

sc.pl.spatial(adata, color='mclust', ax=ax, show=False, spot_size=20, size=20, color_map='viridis')
# sc.pl.spatial(adata, color='mclust', ax=ax, show=False, spot_size=20)
ax.set_title('Clustering: (ARI=%.4f, NMI=%.4f)' % (ARI, NMI))

output_dir = './STAGATE_ARI_NMI'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
output_path = os.path.join(output_dir, "os.svg")
plt.savefig(output_path, dpi=300, bbox_inches='tight')
plt.tight_layout()
# output_dir = ('./STAGATE_ARI_NMI')
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)
# output_path = os.path.join(output_dir, "ba3.svg")
# plt.savefig(output_path, dpi=300, bbox_inches='tight')
plt.show()

# %%
# 保存 adata 为 h5ad 文件
output_dir1 = ('./feature')
if not os.path.exists(output_dir1):
    os.makedirs(output_dir1)
output_path = os.path.join(output_dir1, "osmfish.h5ad")
adata.write_h5ad(output_path)
