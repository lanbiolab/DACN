# %%
import os
import torch
import pandas as pd
import scanpy as sc
from sklearn import metrics
import multiprocessing as mp
from GraphST import GraphST
from pathlib import Path

# %%
data_root = Path('../data/DLPFC')

# sample name
sample_name = '151673'
n_clusters = 5 if sample_name in ['151669', '151670', '151671', '151672'] else 7
adata = sc.read_visium(data_root / sample_name)
print(adata)
adata.var_names_make_unique()

df_meta = pd.read_csv(data_root / sample_name / 'metadata.tsv', sep='\t')
adata.obs['layer_guess'] = df_meta['layer_guess']
# Out:
# /data/hgh/anaconda3/envs/py310-torch25/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /data/hgh/anaconda3/envs/py310-torch25/lib/python3.10/site-packages/anndata/_core/anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 3639 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'spatial'
#     obsm: 'spatial'

# %%
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
model = GraphST.GraphST(adata, device=device)

# train model
adata = model.train()
# Out:
# Begin to train ST data...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 600/600 [00:18<00:00, 32.66it/s]
# Optimization finished for ST data!

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3639 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'layer_guess'
#     var: 'gene_ids', 'feature_types', 'genome', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'spatial', 'hvg', 'log1p'
#     obsm: 'spatial', 'distance_matrix', 'graph_neigh', 'adj', 'label_CSL', 'feat', 'feat_a', 'emb'

# %%
tool = 'leiden' # mclust, leiden, and louvain
radius = 50
# clustering
from GraphST.utils import clustering
clustering(adata, n_clusters, radius=radius, method=tool, start=0.1, end=2.0, increment=0.01, refinement=False)
# Out:
# Searching resolution...
# resolution=1.989999999999999, cluster number=16
# resolution=1.979999999999999, cluster number=17
# resolution=1.969999999999999, cluster number=18
# resolution=1.959999999999999, cluster number=17
# resolution=1.949999999999999, cluster number=16
# resolution=1.939999999999999, cluster number=15
# resolution=1.9299999999999993, cluster number=16
# resolution=1.9199999999999993, cluster number=15
# resolution=1.9099999999999993, cluster number=15
# resolution=1.8999999999999992, cluster number=15
# resolution=1.8899999999999992, cluster number=16
# resolution=1.8799999999999992, cluster number=14
# resolution=1.8699999999999992, cluster number=15
# resolution=1.8599999999999992, cluster number=15
# resolution=1.8499999999999992, cluster number=15
# resolution=1.8399999999999992, cluster number=15
# resolution=1.8299999999999992, cluster number=15
# resolution=1.8199999999999992, cluster number=16
# resolution=1.8099999999999992, cluster number=14
# resolution=1.7999999999999992, cluster number=14
# resolution=1.7899999999999991, cluster number=14
# resolution=1.7799999999999994, cluster number=14
# resolution=1.7699999999999994, cluster number=14
# resolution=1.7599999999999993, cluster number=14
# resolution=1.7499999999999993, cluster number=14
# resolution=1.7399999999999993, cluster number=14
# resolution=1.7299999999999993, cluster number=16
# resolution=1.7199999999999993, cluster number=14
# resolution=1.7099999999999993, cluster number=13
# resolution=1.6999999999999993, cluster number=15
# resolution=1.6899999999999993, cluster number=13
# resolution=1.6799999999999993, cluster number=13
# resolution=1.6699999999999993, cluster number=14
# resolution=1.6599999999999993, cluster number=14
# resolution=1.6499999999999992, cluster number=13
# resolution=1.6399999999999992, cluster number=15
# resolution=1.6299999999999992, cluster number=13
# resolution=1.6199999999999992, cluster number=13
# resolution=1.6099999999999994, cluster number=13
# resolution=1.5999999999999994, cluster number=14
# resolution=1.5899999999999994, cluster number=14
# resolution=1.5799999999999994, cluster number=14
# resolution=1.5699999999999994, cluster number=13
# resolution=1.5599999999999994, cluster number=12
# resolution=1.5499999999999994, cluster number=11
# resolution=1.5399999999999994, cluster number=12
# resolution=1.5299999999999994, cluster number=13
# resolution=1.5199999999999994, cluster number=13
# resolution=1.5099999999999993, cluster number=12
# resolution=1.4999999999999993, cluster number=11
# resolution=1.4899999999999993, cluster number=11
# resolution=1.4799999999999993, cluster number=11
# resolution=1.4699999999999993, cluster number=11
# resolution=1.4599999999999995, cluster number=12
# resolution=1.4499999999999995, cluster number=10
# resolution=1.4399999999999995, cluster number=10
# resolution=1.4299999999999995, cluster number=10
# resolution=1.4199999999999995, cluster number=11
# resolution=1.4099999999999995, cluster number=10
# resolution=1.3999999999999995, cluster number=10
# resolution=1.3899999999999995, cluster number=11
# resolution=1.3799999999999994, cluster number=9
# resolution=1.3699999999999994, cluster number=10
# resolution=1.3599999999999994, cluster number=11
# resolution=1.3499999999999994, cluster number=9
# resolution=1.3399999999999994, cluster number=11
# resolution=1.3299999999999994, cluster number=10
# resolution=1.3199999999999994, cluster number=11
# resolution=1.3099999999999994, cluster number=9
# resolution=1.2999999999999994, cluster number=9
# resolution=1.2899999999999996, cluster number=9
# resolution=1.2799999999999996, cluster number=10
# resolution=1.2699999999999996, cluster number=10
# resolution=1.2599999999999996, cluster number=10
# resolution=1.2499999999999996, cluster number=10
# resolution=1.2399999999999995, cluster number=10
# resolution=1.2299999999999995, cluster number=10
# resolution=1.2199999999999995, cluster number=10
# resolution=1.2099999999999995, cluster number=9
# resolution=1.1999999999999995, cluster number=10
# resolution=1.1899999999999995, cluster number=10
# resolution=1.1799999999999995, cluster number=9
# resolution=1.1699999999999995, cluster number=9
# resolution=1.1599999999999995, cluster number=9
# resolution=1.1499999999999995, cluster number=9
# resolution=1.1399999999999997, cluster number=10
# resolution=1.1299999999999997, cluster number=9
# resolution=1.1199999999999997, cluster number=10
# resolution=1.1099999999999997, cluster number=10
# resolution=1.0999999999999996, cluster number=11
# resolution=1.0899999999999996, cluster number=9
# resolution=1.0799999999999996, cluster number=10
# resolution=1.0699999999999996, cluster number=9
# resolution=1.0599999999999996, cluster number=9
# resolution=1.0499999999999996, cluster number=10
# resolution=1.0399999999999996, cluster number=10
# resolution=1.0299999999999996, cluster number=9
# resolution=1.0199999999999996, cluster number=9
# resolution=1.0099999999999996, cluster number=9
# resolution=0.9999999999999996, cluster number=9
# resolution=0.9899999999999995, cluster number=9
# resolution=0.9799999999999995, cluster number=9
# resolution=0.9699999999999995, cluster number=9
# resolution=0.9599999999999995, cluster number=9
# resolution=0.9499999999999995, cluster number=8
# resolution=0.9399999999999996, cluster number=9
# resolution=0.9299999999999996, cluster number=9
# resolution=0.9199999999999996, cluster number=9
# resolution=0.9099999999999996, cluster number=9
# resolution=0.8999999999999996, cluster number=9
# resolution=0.8899999999999996, cluster number=9
# resolution=0.8799999999999996, cluster number=9
# resolution=0.8699999999999996, cluster number=8
# resolution=0.8599999999999995, cluster number=8
# resolution=0.8499999999999996, cluster number=8
# resolution=0.8399999999999996, cluster number=8
# resolution=0.8299999999999996, cluster number=8
# resolution=0.8199999999999996, cluster number=8
# resolution=0.8099999999999996, cluster number=8
# resolution=0.7999999999999996, cluster number=8
# resolution=0.7899999999999996, cluster number=8
# resolution=0.7799999999999997, cluster number=8
# resolution=0.7699999999999997, cluster number=8
# resolution=0.7599999999999997, cluster number=9
# resolution=0.7499999999999997, cluster number=9
# resolution=0.7399999999999997, cluster number=9
# resolution=0.7299999999999996, cluster number=8
# resolution=0.7199999999999996, cluster number=8
# resolution=0.7099999999999996, cluster number=8
# resolution=0.6999999999999996, cluster number=8
# resolution=0.6899999999999997, cluster number=7

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 3639 × 33538
#     obs: 'in_tissue', 'array_row', 'array_col', 'layer_guess', 'leiden', 'domain', 'louvain'
#     var: 'gene_ids', 'feature_types', 'genome', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std'
#     uns: 'spatial', 'hvg', 'log1p', 'neighbors', 'leiden', 'layer_guess_colors', 'domain_colors', 'leiden_colors', 'louvain'
#     obsm: 'spatial', 'distance_matrix', 'graph_neigh', 'adj', 'label_CSL', 'feat', 'feat_a', 'emb', 'emb_pca'
#     obsp: 'distances', 'connectivities'

# %%
import matplotlib.pyplot as plt
sub_adata = adata[~pd.isnull(adata.obs['layer_guess'])]
ARI = metrics.adjusted_rand_score(sub_adata.obs['layer_guess'], sub_adata.obs['domain'])
NMI = metrics.normalized_mutual_info_score(sub_adata.obs['layer_guess'], sub_adata.obs['domain'])
fig, axes = plt.subplots(1,2,figsize=(4*2, 4))
sc.pl.spatial(adata, color='layer_guess', ax=axes[0], show=False)
sc.pl.spatial(adata, color='domain', ax=axes[1], show=False)
axes[0].set_title('Manual Annotation')
axes[1].set_title('Clustering: (ARI=%.4f, NMI=%.4f)' % (ARI, NMI))
plt.tight_layout()
plt.show()
# Out:
# /data/hgh/anaconda3/envs/py310-torch25/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
# /data/hgh/anaconda3/envs/py310-torch25/lib/python3.10/site-packages/scanpy/plotting/_tools/scatterplots.py:1234: FutureWarning: The default value of 'ignore' for the `na_action` parameter in pandas.Categorical.map is deprecated and will be changed to 'None' in a future version. Please set na_action to the desired value to avoid seeing this warning
#   color_vector = pd.Categorical(values.map(color_map))
